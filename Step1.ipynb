# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedMostafaSal/E2E_DS_Proj/blob/main/Step1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 34411       34412  I am not primarily a developer, but I write co...
# 34412       34413                     I am a developer by profession
# 34413       34414                     I am a developer by profession
# 34414       34415             I am a student who is learning to code
# 34415       34416                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...
